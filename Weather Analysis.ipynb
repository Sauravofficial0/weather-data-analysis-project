# %%
import pandas as pd

# %%
df = pd.read_csv("unstructured_weather_10000_rows.csv")

# %%
df.head()
# Out:
#              Date time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_KM/h  \
# 0  2023-01-31 05:14:27     9.0               1.5       44.0             40.0
# 1  2022-10-19 21:17:16    15.2              14.7       64.0              4.7
# 2  2024-09-13 08:42:54    44.9              36.0       18.0             37.7
# 3  2022-10-21 08:38:02    -2.3              -4.6       27.0             55.0
# 4  2021-09-02 00:03:08    23.9              18.4       53.0             14.9
#
#    Visibility_Km  Press_KPA       Weather
# 0            8.7     101.89        Cloudy
# 1           14.3     102.18  Thunderstorm
# 2            5.8     100.47          Haze
# 3           10.5     100.20        Cloudy
# 4            3.6     102.19          Rain

# %%
df.shape
# Out:
# (10000, 8)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=10000, step=1)

# %%
df.columns
# Out:
# Index(['Date time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_KM/h', 'Visibility_Km', 'Press_KPA', 'Weather'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Date time            object
# Temp_C              float64
# Dew Point Temp_C    float64
# Rel Hum_%           float64
# Wind Speed_KM/h     float64
# Visibility_Km       float64
# Press_KPA           float64
# Weather              object
# dtype: object

# %%
df['Weather'].unique()
# Out:
# array(['Cloudy', 'Thunderstorm', 'Haze', 'Rain', 'Clear', 'Partly Cloudy',
#        'Heavy Rain', 'Mist', 'Sunny', 'Snow', 'Fog'], dtype=object)

# %%
df.nunique()
# Out:
# Date time           9999
# Temp_C               501
# Dew Point Temp_C     593
# Rel Hum_%             90
# Wind Speed_KM/h      601
# Visibility_Km        296
# Press_KPA            501
# Weather               11
# dtype: int64

# %%
df.count()
# Out:
# Date time           10000
# Temp_C               9700
# Dew Point Temp_C    10000
# Rel Hum_%            9700
# Wind Speed_KM/h     10000
# Visibility_Km        9700
# Press_KPA           10000
# Weather             10000
# dtype: int64

# %%
df.isna().sum()
# Out:
# Date time             0
# Temp_C              300
# Dew Point Temp_C      0
# Rel Hum_%           300
# Wind Speed_KM/h       0
# Visibility_Km       300
# Press_KPA             0
# Weather               0
# dtype: int64

# %%
df['Temp_C'].fillna(df['Temp_C'].mean(), inplace=True)
df['Rel Hum_%'].fillna(df['Rel Hum_%'].mean(), inplace=True)
df['Visibility_Km'].fillna(df['Visibility_Km'].mean(), inplace=True)

# %%
df.isna().sum()
# Out:
# Date time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_KM/h     0
# Visibility_Km       0
# Press_KPA           0
# Weather             0
# dtype: int64

# %%
df['Visibility_Km'].mean()
df['Rel Hum_%'].var()
# Out:
# np.float64(647.8627581830348)

# %%
df['Weather'].value_counts()
# Out:
# Weather
# Haze             946
# Rain             946
# Clear            943
# Partly Cloudy    920
# Sunny            909
# Thunderstorm     906
# Snow             903
# Fog              897
# Heavy Rain       890
# Mist             889
# Cloudy           851
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date time         10000 non-null  object
#  1   Temp_C            10000 non-null  float64
#  2   Dew Point Temp_C  10000 non-null  float64
#  3   Rel Hum_%         10000 non-null  float64
#  4   Wind Speed_KM/h   10000 non-null  float64
#  5   Visibility_Km     10000 non-null  float64
#  6   Press_KPA         10000 non-null  float64
#  7   Weather           10000 non-null  object
# dtypes: float64(6), object(2)
# memory usage: 625.1+ KB

# %%
# Q1) Find all the unique 'Wind Speed' values in the data.

# %%
df.head(2)
# Out:
#              Date time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_KM/h  \
# 0  2023-01-31 05:14:27     9.0               1.5       44.0             40.0
# 1  2022-10-19 21:17:16    15.2              14.7       64.0              4.7
#
#    Visibility_Km  Press_KPA       Weather
# 0            8.7     101.89        Cloudy
# 1           14.3     102.18  Thunderstorm

# %%
df.nunique()
# Out:
# Date time           9999
# Temp_C               502
# Dew Point Temp_C     593
# Rel Hum_%             91
# Wind Speed_KM/h      601
# Visibility_Km        297
# Press_KPA            501
# Weather               11
# dtype: int64

# %%
df['Wind Speed_KM/h'].nunique()
# Out:
# 601

# %%
df['Wind Speed_KM/h'].unique() # Answer
# Out:
# array([40. ,  4.7, 37.7, 55. , 14.9, 21.7, 13.9, 49.1, 10.1, 20.8, 36.1,
#        24.3,  3.9, 56.9, 20.3, 26.7, 51.9, 17.5,  1.2, 19. , 59. ,  8.8,
#         1.9, 34.7, 22.3, 47.7, 43.9, 11.1, 33.9, 26.4, 42.8, 24.9,  7.1,
#         3.7, 51.2, 53.5, 20.6,  9.9, 58.7, 32.8, 28.6, 44.5, 34.8, 53.4,
#         1.4, 40.4, 33.1, 57. , 15.5, 51.5, 18.5, 25.8, 12.8, 51.8, 11.7,
#        27.3, 50.1, 15.9,  8. , 33.3, 30.6, 21.4, 39.8,  5.7, 37.3, 12.7,
#         7.7, 54.6, 27.6, 45.8,  5.3,  3.4, 29.7, 18.9,  0.3, 11. , 13.1,
#        17.3, 52.7, 25.2, 40.8,  1.1, 48.8, 14.4,  2.7, 24.6, 22.7, 54.5,
#        52. , 18.3,  1.8, 45.9, 54.4, 46.2, 44.6, 50.6, 39.9, 25.4,  3.8,
#        47.3, 54.3, 30.7, 32. , 24.2, 51.4,  0.9, 37.5,  6.2, 57.5, 58.1,
#        55.8, 27.8, 23. , 42.4, 19.1,  4.1, 54.1, 38.1, 12.4, 43.4,  4.9,
#        38.9, 17.8,  8.6, 28.9, 31. , 49.4, 29.1, 54. , 50.5, 39.1, 22.5,
#        31.6, 16.9, 28.8,  7.8, 50.7, 57.9, 29. , 49.3, 42. , 23.9, 55.7,
# ...

# %%
# Q. 2) Find the number of times when the 'Weather is exactly Clear'.

# %%
df.head(2)
# Out:
#              Date time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_KM/h  \
# 0  2023-01-31 05:14:27     9.0               1.5       44.0             40.0
# 1  2022-10-19 21:17:16    15.2              14.7       64.0              4.7
#
#    Visibility_Km  Press_KPA       Weather
# 0            8.7     101.89        Cloudy
# 1           14.3     102.18  Thunderstorm

# %%
df.Weather.value_counts()
# Out:
# Weather
# Haze             946
# Rain             946
# Clear            943
# Partly Cloudy    920
# Sunny            909
# Thunderstorm     906
# Snow             903
# Fog              897
# Heavy Rain       890
# Mist             889
# Cloudy           851
# Name: count, dtype: int64

# %%
(df['Weather'] == 'Clear').sum() # Answer
# Out:
# np.int64(943)

# %%
# Q. 3) Find the number of times when the 'Wind Speed was exactly 4 km/h'.

# %%
df.head(2)
# Out:
#              Date time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_KM/h  \
# 0  2023-01-31 05:14:27     9.0               1.5       44.0             40.0
# 1  2022-10-19 21:17:16    15.2              14.7       64.0              4.7
#
#    Visibility_Km  Press_KPA       Weather
# 0            8.7     101.89        Cloudy
# 1           14.3     102.18  Thunderstorm

# %%
(df['Wind Speed_KM/h'] == 4).sum() # Answer
# Out:
# np.int64(16)

# %%
df[df['Wind Speed_KM/h'] == 4]
# Out:
#                 Date time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 539   2021-08-22 06:06:13    17.8              17.0       60.0
# 1059  2024-10-31 09:31:18    25.0              24.3       95.0
# 1972  2024-12-09 11:20:44    19.6              10.8       12.0
# 3066  2023-09-02 11:25:03    11.7              11.6       66.0
# 3409  2023-01-18 23:05:35     3.8              -4.7       22.0
# 4031  2023-02-22 21:34:58    38.8              38.0       65.0
# 4574  2022-06-07 13:11:08     0.0              -7.4       17.0
# 5151  2023-02-25 13:38:49    35.3              33.3       42.0
# 5526  2022-08-06 00:56:15    39.5              37.3       77.0
# 5730  2023-04-15 15:10:25     1.7              -0.5       65.0
# 6410  2021-05-04 16:36:02     5.4              -4.5       55.0
# 6851  2023-10-23 02:48:13    -3.0              -5.2       71.0
# 7228  2021-10-02 18:50:19    38.1              34.2       23.0
# 7627  2022-05-23 17:13:42    39.2              35.8       28.0
# ...

# %%
# Q. 4) Find out all the Null Values in the data.

# %%
df.isna().sum() #Answer
# Out:
# Date time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_KM/h     0
# Visibility_Km       0
# Press_KPA           0
# Weather             0
# dtype: int64

# %%
# Q. 5) Rename the column name 'Weather' of the dataframe to 'Weather Condition'.

# %%
df.head(2)
# Out:
#              Date time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_KM/h  \
# 0  2023-01-31 05:14:27     9.0               1.5       44.0             40.0
# 1  2022-10-19 21:17:16    15.2              14.7       64.0              4.7
#
#    Visibility_Km  Press_KPA       Weather
# 0            8.7     101.89        Cloudy
# 1           14.3     102.18  Thunderstorm

# %%
df.rename(columns={'Weather': 'Weather Condition'}, inplace=True) # Answer

# %%
df.head()
# Out:
#              Date time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_KM/h  \
# 0  2023-01-31 05:14:27     9.0               1.5       44.0             40.0
# 1  2022-10-19 21:17:16    15.2              14.7       64.0              4.7
# 2  2024-09-13 08:42:54    44.9              36.0       18.0             37.7
# 3  2022-10-21 08:38:02    -2.3              -4.6       27.0             55.0
# 4  2021-09-02 00:03:08    23.9              18.4       53.0             14.9
#
#    Visibility_Km  Press_KPA Weather Condition
# 0            8.7     101.89            Cloudy
# 1           14.3     102.18      Thunderstorm
# 2            5.8     100.47              Haze
# 3           10.5     100.20            Cloudy
# 4            3.6     102.19              Rain

# %%
# Q. 6) What is the mean 'Visibility' ?

# %%
df['Visibility_Km'].mean() # Answer
# Out:
# np.float64(15.327969072164947)

# %%
# Q. 7) What is the Standard Deviation of 'Pressure'  in this data?

# %%
df.Press_KPA.std() # Answer
# Out:
# np.float64(1.4423158965613418)

# %%
# Q. 8) What is the Variance of 'Relative Humidity' in this data ?

# %%
df['Rel Hum_%'].var # Answer
# Out:
# np.float64(647.8627581830348)

# %%
# Q. 9) Find all instances when 'Snow' was recorded.

# %%
df.head(2)
# Out:
#              Date time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_KM/h  \
# 0  2023-01-31 05:14:27     9.0               1.5       44.0             40.0
# 1  2022-10-19 21:17:16    15.2              14.7       64.0              4.7
#
#    Visibility_Km  Press_KPA Weather Condition
# 0            8.7     101.89            Cloudy
# 1           14.3     102.18      Thunderstorm

# %%
snow_df = df[df['Weather Condition'] == 'Snow']
snow_df # Answer
# Out:
#                 Date time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 34    2022-05-12 01:34:40    15.3               7.6       30.0
# 35    2024-05-16 13:19:22     3.5              -2.5       56.0
# 36    2023-06-19 21:35:54    43.9              34.6       12.0
# 37    2024-05-20 20:18:06    37.7              33.7       39.0
# 66    2022-06-02 19:22:33    43.3              40.8       52.0
# ...                   ...     ...               ...        ...
# 9959  2021-04-22 22:08:35    41.8              36.3       74.0
# 9960  2022-06-07 14:45:52    37.4              34.1       22.0
# 9962  2022-08-15 01:11:41    17.5              14.7       83.0
# 9964  2023-06-29 22:06:24    32.1              29.9       85.0
# 9991  2023-02-07 13:46:00     3.1              -4.0       99.0
#
#       Wind Speed_KM/h  Visibility_Km  Press_KPA Weather Condition
# 34                7.1      23.100000      99.85              Snow
# 35                3.7      19.300000      99.61              Snow
# ...

# %%
# Q. 10) Find all instances when 'Wind Speed is above 24' and 'Visibility is 25'.

# %%
q10_df = df[
    (df['Wind Speed_KM/h'] > 24) &
    (df['Visibility_Km'] == 25)
]
q10_df # Answer
# Out:
#                 Date time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 104   2022-11-29 23:17:34    23.8              18.1  73.000000
# 395   2023-05-20 02:58:25     4.4               4.2  94.000000
# 1365  2023-01-05 08:07:35    13.6              10.6  14.000000
# 1590  2021-07-09 21:06:06    43.9              37.3  61.000000
# 2360  2022-10-10 11:06:13    21.5              13.8  97.000000
# 2889  2023-02-18 18:01:15     3.7               0.9  18.000000
# 3518  2023-09-04 12:21:34    -2.5              -5.0  78.000000
# 4127  2023-11-16 02:27:10    11.2               9.3  57.000000
# 4575  2021-04-10 00:44:15    30.9              28.2  35.000000
# 4684  2022-07-15 12:08:42    38.3              30.9  10.000000
# 6280  2021-09-15 01:30:17    36.8              28.1  30.000000
# 6487  2021-01-18 20:50:12    -3.5              -5.0  55.000000
# 6670  2024-01-18 05:09:19     2.8              -1.0  14.000000
# 7003  2024-10-19 08:16:57     5.0              -0.8  14.000000
# ...

# %%
df[(df['Wind Speed_KM/h'] > 24) & (df['Visibility_Km'] == 25)]
# Out:
#                 Date time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 104   2022-11-29 23:17:34    23.8              18.1  73.000000
# 395   2023-05-20 02:58:25     4.4               4.2  94.000000
# 1365  2023-01-05 08:07:35    13.6              10.6  14.000000
# 1590  2021-07-09 21:06:06    43.9              37.3  61.000000
# 2360  2022-10-10 11:06:13    21.5              13.8  97.000000
# 2889  2023-02-18 18:01:15     3.7               0.9  18.000000
# 3518  2023-09-04 12:21:34    -2.5              -5.0  78.000000
# 4127  2023-11-16 02:27:10    11.2               9.3  57.000000
# 4575  2021-04-10 00:44:15    30.9              28.2  35.000000
# 4684  2022-07-15 12:08:42    38.3              30.9  10.000000
# 6280  2021-09-15 01:30:17    36.8              28.1  30.000000
# 6487  2021-01-18 20:50:12    -3.5              -5.0  55.000000
# 6670  2024-01-18 05:09:19     2.8              -1.0  14.000000
# 7003  2024-10-19 08:16:57     5.0              -0.8  14.000000
# ...

# %%
q10_df.shape[0] # Answer
# Out:
# 19

# %%
# Q. 11) What is the Mean value of each column against each 'Weather Condition ?

# %%
df.head(2)
# Out:
#              Date time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_KM/h  \
# 0  2023-01-31 05:14:27     9.0               1.5       44.0             40.0
# 1  2022-10-19 21:17:16    15.2              14.7       64.0              4.7
#
#    Visibility_Km  Press_KPA Weather Condition
# 0            8.7     101.89            Cloudy
# 1           14.3     102.18      Thunderstorm

# %%
df.groupby('Weather Condition').mean(numeric_only=True) # Answer
# Out:
#                       Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_KM/h  \
# Weather Condition
# Clear              19.846419         14.686850  55.606949        29.523436
# Cloudy             20.432232         15.199530  55.215455        30.191304
# Fog                19.607892         14.622742  53.622507        30.764326
# Haze               19.941228         14.658034  54.278766        29.328330
# Heavy Rain         20.232203         15.125281  54.892663        29.804719
# Mist               20.110610         15.015411  55.021455        28.940607
# Partly Cloudy      20.175552         15.014348  52.543901        30.389130
# Rain               19.461127         14.579810  54.881342        30.837844
# Snow               19.150077         13.980731  55.335320        30.419158
# Sunny              19.864327         14.745215  55.458737        29.349945
# Thunderstorm       19.544782         14.405629  54.213722        29.275938
#
#                    Visibility_Km   Press_KPA
# ...

# %%
# Q. 12) What is the Minimum & Maximum value of each column against each 'Weather Condition ?

# %%
df.groupby('Weather Condition').min(numeric_only=True) # minimm values answer
# Out:
#                    Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_KM/h  \
# Weather Condition
# Clear                -5.0             -13.6       10.0              0.0
# Cloudy               -5.0             -13.3       10.0              0.1
# Fog                  -5.0             -14.4       10.0              0.1
# Haze                 -5.0             -14.2       10.0              0.0
# Heavy Rain           -5.0             -14.2       10.0              0.0
# Mist                 -5.0             -13.7       10.0              0.0
# Partly Cloudy        -5.0             -14.1       10.0              0.1
# Rain                 -4.8             -13.5       10.0              0.0
# Snow                 -4.8             -14.6       10.0              0.0
# Sunny                -5.0             -13.6       10.0              0.0
# Thunderstorm         -4.9             -13.4       10.0              0.1
#
#                    Visibility_Km  Press_KPA
# Weather Condition
# ...

# %%
df.groupby('Weather Condition').max(numeric_only=True) # maximum values answer
# Out:
#                    Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_KM/h  \
# Weather Condition
# Clear                45.0              44.5       99.0             60.0
# Cloudy               45.0              43.6       99.0             59.9
# Fog                  45.0              44.2       99.0             60.0
# Haze                 44.9              44.3       99.0             60.0
# Heavy Rain           45.0              44.8       99.0             59.9
# Mist                 44.9              43.8       99.0             59.9
# Partly Cloudy        44.9              44.6       99.0             60.0
# Rain                 45.0              44.5       99.0             59.9
# Snow                 45.0              44.9       99.0             60.0
# Sunny                44.9              43.7       99.0             59.9
# Thunderstorm         44.9              44.1       99.0             60.0
#
#                    Visibility_Km  Press_KPA
# Weather Condition
# ...

# %%
# Q. 13) Show all the Records where Weather Condition is Fog.

# %%
fog_df = df[df['Weather Condition'] == 'Fog']
fog_df # answer
# Out:
#                 Date time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 45    2024-10-29 04:17:01    25.6              17.0  85.000000
# 60    2022-10-22 09:42:41    20.2              17.0  80.000000
# 71    2024-10-23 01:03:15    38.4              35.5  10.000000
# 87    2023-07-29 19:35:25    11.0               7.8  23.000000
# 97    2021-04-10 08:49:37    19.6              14.8  29.000000
# ...                   ...     ...               ...        ...
# 9989  2023-03-10 02:03:17    44.7              36.5  51.000000
# 9990  2024-11-27 09:39:01    29.9              28.5  15.000000
# 9993  2022-09-25 08:40:36     3.6              -2.2  92.000000
# 9998  2021-03-06 15:16:21    24.3              19.2  80.000000
# 9999  2022-12-29 22:52:40    34.1              33.4  54.639691
#
#       Wind Speed_KM/h  Visibility_Km  Press_KPA Weather Condition
# 45               34.8           27.9      98.95               Fog
# 60               50.1           23.0     101.77               Fog
# ...

# %%
# Q. 14) Find all instances when 'Weather is Clear' or 'Visibility is above 40'.

# %%
q14_df = df[
    (df['Weather Condition'] == 'Clear') |
    (df['Visibility_Km'] > 40)
]
q14_df # Answer
# Out:
#                 Date time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 5     2021-06-04 02:38:12    -0.9              -7.3       30.0
# 7     2021-11-06 10:37:10    17.0               7.2       57.0
# 12    2022-01-02 02:48:03    10.2               3.2       67.0
# 30    2024-05-15 15:34:45    44.8              39.9       44.0
# 32    2024-07-01 07:21:15    21.9              12.7       58.0
# ...                   ...     ...               ...        ...
# 9963  2023-02-23 05:30:31    21.8              21.7       35.0
# 9971  2021-02-13 10:05:31    29.9              22.1       86.0
# 9987  2023-08-16 06:57:55    37.5              32.9       81.0
# 9988  2023-02-01 19:12:19    -1.6              -8.8       85.0
# 9994  2023-06-05 13:17:43    36.9              35.0       91.0
#
#       Wind Speed_KM/h  Visibility_Km  Press_KPA Weather Condition
# 5                21.7      13.200000     102.30             Clear
# 7                49.1      18.100000     102.54             Clear
# ...

# %%
q14_df.shape[0] # Answer
# Out:
# 943

# %%
# Q. 15) Find all instances when :
# A. 'Weather is Clear' and 'Relative Humidity is greater than 50'
# or
# B. 'Visibility is above 40'

# %%
q15_df = df[
    ((df['Weather Condition'] == 'Clear') & (df['Rel Hum_%'] > 50)) |
    (df['Visibility_Km'] > 40)
]
q15_df
# Out:
#                 Date time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 7     2021-11-06 10:37:10    17.0               7.2       57.0
# 12    2022-01-02 02:48:03    10.2               3.2       67.0
# 32    2024-07-01 07:21:15    21.9              12.7       58.0
# 75    2024-11-07 05:10:30    -0.4              -4.1       93.0
# 76    2023-03-19 15:00:59    17.9               9.9       89.0
# ...                   ...     ...               ...        ...
# 9945  2022-02-08 05:51:16     4.1              -1.6       81.0
# 9971  2021-02-13 10:05:31    29.9              22.1       86.0
# 9987  2023-08-16 06:57:55    37.5              32.9       81.0
# 9988  2023-02-01 19:12:19    -1.6              -8.8       85.0
# 9994  2023-06-05 13:17:43    36.9              35.0       91.0
#
#       Wind Speed_KM/h  Visibility_Km  Press_KPA Weather Condition
# 7                49.1      18.100000     102.54             Clear
# 12                3.9      11.400000      99.52             Clear
# ...

# %%
q15_df.shape[0]
# Out:
# 537
